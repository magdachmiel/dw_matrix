# %%
from google.colab import drive

# %%
ROOT='/content/drive'
drive.mount(ROOT)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
HOME= ROOT + '/My Drive/Colab Notebooks'
HOME
# Out:
# '/content/drive/My Drive/Colab Notebooks'

# %%
cd {HOME}
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
ls
# Out:
# Challenge#4/  Challenge#5/  dw_matrix/  Transformacja#1/  Transformacja#3/

# %%
GITHUB_TOKEN = '67ee669657161761771f153b98b117e9fd75d947'
GITHUB_URL = 'https://{0}@github.com/magdachmiel/dw_matrix.git'.format(GITHUB_TOKEN)

# %%
# !git clone {GITHUB_URL}
# Out:
# Cloning into 'dw_matrix'...
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 11 (delta 3), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (11/11), done.

# %%
cd dw_matrix
# Out:
# /content/drive/My Drive/Colab Notebooks/dw_matrix

# %%
# !mkdir ./transformacja1

# %%
ls
# Out:
# HelloGitHub.ipynb  transformacja1day2.ipynb

# %%
cd Transformacja#1/
# Out:
# /content/drive/My Drive/Colab Notebooks/dw_matrix/Transformacja#1
